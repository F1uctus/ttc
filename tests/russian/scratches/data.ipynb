# %%
import ttc

# %%
cc = ttc.load("ru")

# %%
with open("./scratch.txt", encoding="utf-8") as f:
    dialogues = [
        cc.extract_dialogue(t)
        for t in f.read().split("-" * 25)
    ]

# %%
dialogues
# Out:
# [Я с каждым сделаю то же самое, если придется.,
#  Дядя, что это такое — загородки от буржуев?,
#  Ничего, ты будешь спать на моем животе,,
#  Я этого, маленькая, не знаю: я же — ничто!,
#  И что же мы будем делать вместо этого?,
#  Булыжник какой-то,,
#  Ведь второй час.,
#  Ну так ведь это интересно,
#
#  Это очень, очень интересно…,
#  Ага,
#
#  Это точно.,
#  Если бы допил,
#
#  ему бы нечего было вылить себе на голову, правда?,
#  Ах, Боже мой! Боже мой! что же это такое!
#
#  Спать так спать!,
#  Ну ладно.
#
#  Курп, порежь себе руку.,
#  Еще чего,
#
#  Старший может командовать лишь на поле боя.,
#  Эй, Газ,,
#  Ах это ужасно, ужасно!
#
#  Я не понимаю только – как можно жить с такими мыслями.,
#  Хватит, Тук!
#
#  Я тут не…,
#  Ордер...,
#  У вас всегда так мочой воняет?
#
#  Бомжи ночуют?,
#  Борис Владимирович,
#
#  пойдемте, не тяните время.,
#  Она уже мертвая!,
#  Я должен сообщить,
#
#  что ты держишь мой клятвенный камень.,
#  Это почему ж?
#
# ...
